# %% [markdown]
# <a href="https://colab.research.google.com/github/Fartela/fart/blob/main/VibeVoice_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # VibeVoice Colab
# ### 🏷️ **Credits & License**
#
# * 🔗 [VibeVoice GitHub Repository](https://github.com/microsoft/VibeVoice)
# * 🤗 [VibeVoice on Hugging Face](https://huggingface.co/microsoft/VibeVoice-1.5B)
# * 📄 **License**: Provided under the [MIT License](https://github.com/microsoft/VibeVoice/blob/main/LICENSE)
#
# ### ⚠️ **Usage Disclaimer**
#
# This tool enables **AI-generated podcast creation** using cloned voices. While it can be a powerful resource for storytelling, education, and creative projects, it also carries risks if misused. By using this tool, you agree to the following guidelines:
#
# * **No Misrepresentation**: Do not use cloned voices to impersonate real people or mislead listeners into believing AI-generated voices are authentic recordings without disclosure.
# * **Transparency**: Clearly disclose when podcast content has been generated with AI, including synthetic voices or AI-written scripts.
# * **No Harmful Content**: Do not produce or distribute content that promotes hate, harassment, misinformation, defamation, or any form of harmful/deceptive material.
# * **Legal Compliance**: Ensure all use of this tool complies with copyright laws, data protection regulations, and all applicable legal and ethical standards.
# * **Respect for Consent**: Do not replicate or publish anyone’s voice without explicit permission.
#
# > ⚖️ **Legal Responsibility**
#
# > The developers of this tool disclaim all liability for misuse. **Users bear full responsibility** for ensuring that their usage complies with all applicable laws, regulations, and ethical guidelines.

# %%
# @title Install VibeVoice

# %cd /content/


# !git clone https://github.com/microsoft/VibeVoice.git
# Download colab.py
# %cd /content/VibeVoice/demo
# !wget https://raw.githubusercontent.com/NeuralFalconYT/VibeVoice/refs/heads/main/demo/colab.py


# (Optional) If you experience compatibility issues with the latest version, you can use a pinned fork instead:
# !git clone https://github.com/NeuralFalconYT/VibeVoice.git



# %cd /content/VibeVoice/
# !pip install -e .
# !pip install pydub>=0.25.1

from IPython.display import clear_output
clear_output()

# %%
#@title Run Official Gradio UI
# !python /content/VibeVoice/demo/gradio_demo.py --model_path "microsoft/VibeVoice-1.5B" --inference_steps 10 --share

# %%
#@title Automatically save podcast to your Google Drive [Optional]
Enable_Drive_Save= False  # @param {type: "boolean"}
if Enable_Drive_Save:
  from google.colab import drive
  drive.mount('/content/gdrive/')

# %%
#@title Run VibeVoice Podcast
# !python /content/VibeVoice/demo/colab.py --model_path microsoft/VibeVoice-1.5B --inference_steps 10 --debug --share
# Out:
# 2025-11-15 20:11:40.654366: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763237500.674718     932 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763237500.680689     932 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763237500.695609     932 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763237500.695634     932 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763237500.695638     932 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763237500.695643     932 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-15 20:11:40.700212: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:vibevoice.modular.modular_vibevoice_tokenizer:APEX FusedRMSNorm not available, using native implementation
# 📂 Download directory: /content/VibeVoice/VibeVoice-1.5B
# 📦 Found 9 files in repo 'microsoft/VibeVoice-1.5B'. Checking cache ...
# Processing files:   0% 0/9 [00:00<?, ?file/s]
# .gitattributes:   0% 0.00/1.57k [00:00<?, ?B/s]
# .gitattributes: 16.0kB [00:00, 92.3kB/s]
# ⬇️ Downloaded: .gitattributes
# Processing files:  11% 1/9 [00:00<00:02,  3.13file/s]
# README.md:   0% 0.00/7.10k [00:00<?, ?B/s]
# README.md: 16.0kB [00:00, 113kB/s]
# ⬇️ Downloaded: README.md
# Processing files:  22% 2/9 [00:00<00:02,  3.34file/s]
# config.json:   0% 0.00/2.70k [00:00<?, ?B/s]
# config.json: 16.0kB [00:00, 49.0kB/s]
# ⬇️ Downloaded: config.json
# Processing files:  33% 3/9 [00:01<00:02,  2.38file/s]
# Fig1.png:   0% 0.00/150k [00:00<?, ?B/s]
# Fig1.png: 160kB [00:00, 1.07MB/s]
# ⬇️ Downloaded: Fig1.png
# Processing files:  44% 4/9 [00:01<00:01,  2.55file/s]
# model-00001-of-00003.safetensors:   0% 0.00/1.84G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0% 8.00k/1.84G [00:00<9:15:04, 59.3kB/s]
# model-00001-of-00003.safetensors:   1% 14.5M/1.84G [00:00<00:25, 77.2MB/s]
# model-00001-of-00003.safetensors:   2% 29.5M/1.84G [00:00<00:18, 108MB/s]
# model-00001-of-00003.safetensors:   3% 54.0M/1.84G [00:00<00:11, 163MB/s]
# model-00001-of-00003.safetensors:   4% 78.8M/1.84G [00:00<00:09, 196MB/s]
# model-00001-of-00003.safetensors:   5% 98.2M/1.84G [00:00<00:10, 173MB/s]
# model-00001-of-00003.safetensors:   7% 123M/1.84G [00:00<00:09, 199MB/s]
# model-00001-of-00003.safetensors:   8% 153M/1.84G [00:00<00:07, 231MB/s]
# model-00001-of-00003.safetensors:  10% 183M/1.84G [00:00<00:06, 258MB/s]
# model-00001-of-00003.safetensors:  11% 212M/1.84G [00:01<00:06, 271MB/s]
# model-00001-of-00003.safetensors:  13% 238M/1.84G [00:01<00:06, 262MB/s]
# model-00001-of-00003.safetensors:  14% 264M/1.84G [00:01<00:06, 255MB/s]
# model-00001-of-00003.safetensors:  15% 289M/1.84G [00:01<00:06, 255MB/s]
# model-00001-of-00003.safetensors:  17% 313M/1.84G [00:01<00:06, 251MB/s]
# model-00001-of-00003.safetensors:  18% 337M/1.84G [00:01<00:06, 251MB/s]
# model-00001-of-00003.safetensors:  19% 363M/1.84G [00:01<00:06, 256MB/s]
# model-00001-of-00003.safetensors:  21% 387M/1.84G [00:01<00:06, 256MB/s]
# model-00001-of-00003.safetensors:  22% 413M/1.84G [00:01<00:05, 260MB/s]
# model-00001-of-00003.safetensors:  23% 438M/1.84G [00:02<00:05, 254MB/s]
# model-00001-of-00003.safetensors:  25% 462M/1.84G [00:02<00:06, 247MB/s]
# model-00001-of-00003.safetensors:  26% 486M/1.84G [00:02<00:06, 234MB/s]
# model-00001-of-00003.safetensors:  27% 511M/1.84G [00:02<00:05, 243MB/s]
# model-00001-of-00003.safetensors:  29% 540M/1.84G [00:02<00:05, 260MB/s]
# model-00001-of-00003.safetensors:  30% 565M/1.84G [00:02<00:06, 228MB/s]
# model-00001-of-00003.safetensors:  31% 588M/1.84G [00:02<00:05, 231MB/s]
# model-00001-of-00003.safetensors:  32% 611M/1.84G [00:02<00:05, 233MB/s]
# model-00001-of-00003.safetensors:  34% 634M/1.84G [00:02<00:05, 236MB/s]
# model-00001-of-00003.safetensors:  35% 658M/1.84G [00:03<00:05, 239MB/s]
# model-00001-of-00003.safetensors:  36% 681M/1.84G [00:03<00:13, 90.7MB/s]
# model-00001-of-00003.safetensors:  38% 709M/1.84G [00:03<00:10, 118MB/s]
# model-00001-of-00003.safetensors:  39% 742M/1.84G [00:03<00:07, 156MB/s]
# model-00001-of-00003.safetensors:  41% 775M/1.84G [00:03<00:06, 192MB/s]
# model-00001-of-00003.safetensors:  43% 808M/1.84G [00:04<00:05, 224MB/s]
# model-00001-of-00003.safetensors:  45% 840M/1.84G [00:04<00:04, 251MB/s]
# model-00001-of-00003.safetensors:  46% 872M/1.84G [00:04<00:03, 271MB/s]
# model-00001-of-00003.safetensors:  48% 902M/1.84G [00:04<00:04, 230MB/s]
# model-00001-of-00003.safetensors:  49% 930M/1.84G [00:04<00:04, 243MB/s]
# model-00001-of-00003.safetensors:  51% 956M/1.84G [00:04<00:03, 246MB/s]
# model-00001-of-00003.safetensors:  52% 982M/1.84G [00:04<00:03, 254MB/s]
# model-00001-of-00003.safetensors:  54% 0.99G/1.84G [00:04<00:03, 270MB/s]
# model-00001-of-00003.safetensors:  55% 1.02G/1.84G [00:05<00:03, 222MB/s]
# model-00001-of-00003.safetensors:  57% 1.04G/1.84G [00:05<00:03, 243MB/s]
# model-00001-of-00003.safetensors:  58% 1.07G/1.84G [00:05<00:03, 264MB/s]
# model-00001-of-00003.safetensors:  60% 1.10G/1.84G [00:05<00:02, 280MB/s]
# model-00001-of-00003.safetensors:  62% 1.14G/1.84G [00:05<00:02, 295MB/s]
# model-00001-of-00003.safetensors:  63% 1.17G/1.84G [00:05<00:02, 304MB/s]
# model-00001-of-00003.safetensors:  65% 1.19G/1.84G [00:05<00:02, 302MB/s]
# model-00001-of-00003.safetensors:  67% 1.22G/1.84G [00:05<00:02, 248MB/s]
# model-00001-of-00003.safetensors:  68% 1.25G/1.84G [00:05<00:02, 239MB/s]
# model-00001-of-00003.safetensors:  69% 1.27G/1.84G [00:06<00:02, 250MB/s]
# model-00001-of-00003.safetensors:  71% 1.30G/1.84G [00:06<00:02, 211MB/s]
# model-00001-of-00003.safetensors:  72% 1.32G/1.84G [00:06<00:02, 226MB/s]
# model-00001-of-00003.safetensors:  73% 1.35G/1.84G [00:06<00:02, 241MB/s]
# model-00001-of-00003.safetensors:  75% 1.37G/1.84G [00:06<00:02, 218MB/s]
# model-00001-of-00003.safetensors:  76% 1.40G/1.84G [00:06<00:02, 231MB/s]
# model-00001-of-00003.safetensors:  77% 1.42G/1.84G [00:06<00:01, 239MB/s]
# model-00001-of-00003.safetensors:  79% 1.45G/1.84G [00:06<00:01, 237MB/s]
# model-00001-of-00003.safetensors:  80% 1.47G/1.84G [00:07<00:02, 194MB/s]
# model-00001-of-00003.safetensors:  81% 1.49G/1.84G [00:07<00:02, 182MB/s]
# model-00001-of-00003.safetensors:  82% 1.51G/1.84G [00:07<00:01, 197MB/s]
# model-00001-of-00003.safetensors:  83% 1.53G/1.84G [00:07<00:01, 184MB/s]
# model-00001-of-00003.safetensors:  85% 1.56G/1.84G [00:07<00:01, 220MB/s]
# model-00001-of-00003.safetensors:  87% 1.59G/1.84G [00:07<00:01, 253MB/s]
# model-00001-of-00003.safetensors:  88% 1.62G/1.84G [00:07<00:00, 270MB/s]
# model-00001-of-00003.safetensors:  90% 1.65G/1.84G [00:07<00:00, 282MB/s]
# model-00001-of-00003.safetensors:  92% 1.68G/1.84G [00:07<00:00, 293MB/s]
# model-00001-of-00003.safetensors:  93% 1.72G/1.84G [00:08<00:00, 308MB/s]
# model-00001-of-00003.safetensors:  95% 1.74G/1.84G [00:08<00:00, 220MB/s]
# model-00001-of-00003.safetensors:  96% 1.77G/1.84G [00:08<00:00, 210MB/s]
# model-00001-of-00003.safetensors:  98% 1.79G/1.84G [00:08<00:00, 226MB/s]
# model-00001-of-00003.safetensors: 1.84GB [00:08, 226MB/s]
# ⬇️ Downloaded: model-00001-of-00003.safetensors
# Processing files:  56% 5/9 [00:10<00:13,  3.46s/file]
# model-00002-of-00003.safetensors:   0% 0.00/1.85G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0% 8.00k/1.85G [00:00<10:59:33, 50.1kB/s]
# model-00002-of-00003.safetensors:   1% 20.6M/1.85G [00:00<00:19, 101MB/s]
# model-00002-of-00003.safetensors:   3% 52.1M/1.85G [00:00<00:10, 188MB/s]
# model-00002-of-00003.safetensors:   4% 80.0M/1.85G [00:00<00:08, 225MB/s]
# model-00002-of-00003.safetensors:   5% 103M/1.85G [00:00<00:08, 225MB/s]
# model-00002-of-00003.safetensors:   7% 127M/1.85G [00:00<00:07, 232MB/s]
# model-00002-of-00003.safetensors:   8% 153M/1.85G [00:00<00:07, 245MB/s]
# model-00002-of-00003.safetensors:   9% 178M/1.85G [00:00<00:07, 250MB/s]
# model-00002-of-00003.safetensors:  11% 209M/1.85G [00:00<00:06, 274MB/s]
# model-00002-of-00003.safetensors:  12% 236M/1.85G [00:01<00:06, 263MB/s]
# model-00002-of-00003.safetensors:  14% 261M/1.85G [00:01<00:06, 260MB/s]
# model-00002-of-00003.safetensors:  15% 286M/1.85G [00:01<00:07, 239MB/s]
# model-00002-of-00003.safetensors:  17% 315M/1.85G [00:01<00:06, 256MB/s]
# model-00002-of-00003.safetensors:  18% 346M/1.85G [00:01<00:05, 277MB/s]
# model-00002-of-00003.safetensors:  20% 373M/1.85G [00:01<00:05, 278MB/s]
# model-00002-of-00003.safetensors:  21% 404M/1.85G [00:01<00:05, 293MB/s]
# model-00002-of-00003.safetensors:  23% 438M/1.85G [00:01<00:04, 311MB/s]
# model-00002-of-00003.safetensors:  25% 471M/1.85G [00:01<00:04, 321MB/s]
# model-00002-of-00003.safetensors:  27% 502M/1.85G [00:02<00:04, 315MB/s]
# model-00002-of-00003.safetensors:  28% 537M/1.85G [00:02<00:04, 329MB/s]
# model-00002-of-00003.safetensors:  30% 571M/1.85G [00:02<00:04, 337MB/s]
# model-00002-of-00003.safetensors:  32% 603M/1.85G [00:02<00:04, 336MB/s]
# model-00002-of-00003.safetensors:  34% 635M/1.85G [00:02<00:03, 330MB/s]
# model-00002-of-00003.safetensors:  35% 667M/1.85G [00:02<00:04, 302MB/s]
# model-00002-of-00003.safetensors:  37% 696M/1.85G [00:02<00:04, 293MB/s]
# model-00002-of-00003.safetensors:  38% 724M/1.85G [00:02<00:04, 279MB/s]
# model-00002-of-00003.safetensors:  40% 751M/1.85G [00:02<00:04, 269MB/s]
# model-00002-of-00003.safetensors:  41% 777M/1.85G [00:03<00:04, 256MB/s]
# model-00002-of-00003.safetensors:  42% 802M/1.85G [00:03<00:04, 259MB/s]
# model-00002-of-00003.safetensors:  44% 827M/1.85G [00:03<00:04, 257MB/s]
# model-00002-of-00003.safetensors:  45% 852M/1.85G [00:05<00:28, 38.1MB/s]
# model-00002-of-00003.safetensors:  46% 872M/1.85G [00:05<00:22, 48.2MB/s]
# model-00002-of-00003.safetensors:  48% 902M/1.85G [00:05<00:15, 67.4MB/s]
# model-00002-of-00003.safetensors:  49% 931M/1.85G [00:05<00:11, 90.3MB/s]
# model-00002-of-00003.safetensors:  50% 955M/1.85G [00:05<00:09, 107MB/s]
# model-00002-of-00003.safetensors:  52% 977M/1.85G [00:05<00:08, 119MB/s]
# model-00002-of-00003.safetensors:  53% 0.98G/1.85G [00:06<00:06, 144MB/s]
# model-00002-of-00003.safetensors:  54% 1.00G/1.85G [00:06<00:05, 155MB/s]
# model-00002-of-00003.safetensors:  55% 1.02G/1.85G [00:06<00:05, 170MB/s]
# model-00002-of-00003.safetensors:  57% 1.04G/1.85G [00:06<00:05, 166MB/s]
# model-00002-of-00003.safetensors:  58% 1.06G/1.85G [00:06<00:05, 157MB/s]
# model-00002-of-00003.safetensors:  59% 1.08G/1.85G [00:06<00:04, 171MB/s]
# model-00002-of-00003.safetensors:  60% 1.11G/1.85G [00:06<00:04, 195MB/s]
# model-00002-of-00003.safetensors:  61% 1.13G/1.85G [00:06<00:03, 205MB/s]
# model-00002-of-00003.safetensors:  62% 1.15G/1.85G [00:06<00:03, 218MB/s]
# model-00002-of-00003.safetensors:  64% 1.18G/1.85G [00:07<00:03, 230MB/s]
# model-00002-of-00003.safetensors:  65% 1.20G/1.85G [00:07<00:02, 242MB/s]
# model-00002-of-00003.safetensors:  67% 1.23G/1.85G [00:07<00:02, 257MB/s]
# model-00002-of-00003.safetensors:  68% 1.26G/1.85G [00:07<00:02, 274MB/s]
# model-00002-of-00003.safetensors:  70% 1.29G/1.85G [00:09<00:15, 39.8MB/s]
# model-00002-of-00003.safetensors:  71% 1.32G/1.85G [00:09<00:09, 57.2MB/s]
# model-00002-of-00003.safetensors:  73% 1.35G/1.85G [00:09<00:06, 79.0MB/s]
# model-00002-of-00003.safetensors:  75% 1.38G/1.85G [00:09<00:04, 102MB/s]
# model-00002-of-00003.safetensors:  76% 1.41G/1.85G [00:09<00:03, 131MB/s]
# model-00002-of-00003.safetensors:  78% 1.44G/1.85G [00:10<00:02, 147MB/s]
# model-00002-of-00003.safetensors:  79% 1.47G/1.85G [00:10<00:02, 166MB/s]
# model-00002-of-00003.safetensors:  81% 1.49G/1.85G [00:10<00:02, 179MB/s]
# model-00002-of-00003.safetensors:  82% 1.52G/1.85G [00:10<00:01, 178MB/s]
# model-00002-of-00003.safetensors:  83% 1.54G/1.85G [00:10<00:02, 164MB/s]
# model-00002-of-00003.safetensors:  85% 1.56G/1.85G [00:10<00:01, 184MB/s]
# model-00002-of-00003.safetensors:  86% 1.58G/1.85G [00:10<00:01, 199MB/s]
# model-00002-of-00003.safetensors:  87% 1.61G/1.85G [00:10<00:01, 228MB/s]
# model-00002-of-00003.safetensors:  89% 1.64G/1.85G [00:10<00:00, 244MB/s]
# model-00002-of-00003.safetensors:  90% 1.67G/1.85G [00:11<00:00, 266MB/s]
# model-00002-of-00003.safetensors:  92% 1.70G/1.85G [00:11<00:00, 285MB/s]
# model-00002-of-00003.safetensors:  94% 1.73G/1.85G [00:11<00:00, 303MB/s]
# model-00002-of-00003.safetensors:  96% 1.76G/1.85G [00:11<00:00, 282MB/s]
# model-00002-of-00003.safetensors:  97% 1.79G/1.85G [00:11<00:00, 247MB/s]
# model-00002-of-00003.safetensors: 1.85GB [00:11, 169MB/s]
# ⬇️ Downloaded: model-00002-of-00003.safetensors
# Processing files:  67% 6/9 [00:22<00:19,  6.33s/file]
# model-00003-of-00003.safetensors:   0% 0.00/1.35G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0% 8.00k/1.35G [00:00<9:56:31, 40.5kB/s]
# model-00003-of-00003.safetensors:   1% 8.77M/1.35G [00:00<00:37, 38.1MB/s]
# model-00003-of-00003.safetensors:   3% 40.8M/1.35G [00:00<00:09, 149MB/s]
# model-00003-of-00003.safetensors:   5% 72.4M/1.35G [00:00<00:06, 212MB/s]
# model-00003-of-00003.safetensors:   7% 99.7M/1.35G [00:00<00:05, 237MB/s]
# model-00003-of-00003.safetensors:   9% 131M/1.35G [00:00<00:04, 267MB/s]
# model-00003-of-00003.safetensors:  12% 160M/1.35G [00:00<00:04, 276MB/s]
# model-00003-of-00003.safetensors:  14% 189M/1.35G [00:00<00:04, 287MB/s]
# model-00003-of-00003.safetensors:  16% 221M/1.35G [00:01<00:04, 301MB/s]
# model-00003-of-00003.safetensors:  18% 251M/1.35G [00:01<00:03, 307MB/s]
# model-00003-of-00003.safetensors:  20% 281M/1.35G [00:01<00:04, 275MB/s]
# model-00003-of-00003.safetensors:  22% 311M/1.35G [00:01<00:03, 286MB/s]
# model-00003-of-00003.safetensors:  25% 344M/1.35G [00:01<00:03, 304MB/s]
# model-00003-of-00003.safetensors:  27% 374M/1.35G [00:01<00:03, 302MB/s]
# model-00003-of-00003.safetensors:  29% 403M/1.35G [00:01<00:03, 298MB/s]
# model-00003-of-00003.safetensors:  31% 434M/1.35G [00:01<00:03, 306MB/s]
# model-00003-of-00003.safetensors:  34% 465M/1.35G [00:01<00:03, 312MB/s]
# model-00003-of-00003.safetensors:  36% 495M/1.35G [00:01<00:02, 310MB/s]
# model-00003-of-00003.safetensors:  38% 527M/1.35G [00:02<00:02, 318MB/s]
# model-00003-of-00003.safetensors:  41% 560M/1.35G [00:02<00:02, 325MB/s]
# model-00003-of-00003.safetensors:  43% 592M/1.35G [00:02<00:02, 328MB/s]
# model-00003-of-00003.safetensors:  45% 624M/1.35G [00:02<00:02, 329MB/s]
# model-00003-of-00003.safetensors:  47% 655M/1.35G [00:02<00:02, 299MB/s]
# model-00003-of-00003.safetensors:  49% 684M/1.35G [00:02<00:02, 291MB/s]
# model-00003-of-00003.safetensors:  52% 712M/1.35G [00:02<00:02, 292MB/s]
# model-00003-of-00003.safetensors:  54% 740M/1.35G [00:02<00:02, 263MB/s]
# model-00003-of-00003.safetensors:  55% 766M/1.35G [00:02<00:02, 260MB/s]
# model-00003-of-00003.safetensors:  57% 791M/1.35G [00:03<00:02, 252MB/s]
# model-00003-of-00003.safetensors:  60% 823M/1.35G [00:03<00:02, 273MB/s]
# model-00003-of-00003.safetensors:  61% 849M/1.35G [00:03<00:02, 261MB/s]
# model-00003-of-00003.safetensors:  63% 876M/1.35G [00:03<00:01, 268MB/s]
# model-00003-of-00003.safetensors:  65% 902M/1.35G [00:03<00:02, 183MB/s]
# model-00003-of-00003.safetensors:  67% 928M/1.35G [00:03<00:02, 203MB/s]
# model-00003-of-00003.safetensors:  69% 960M/1.35G [00:03<00:01, 234MB/s]
# model-00003-of-00003.safetensors:  72% 992M/1.35G [00:03<00:01, 259MB/s]
# model-00003-of-00003.safetensors:  74% 1.00G/1.35G [00:04<00:01, 277MB/s]
# model-00003-of-00003.safetensors:  76% 1.03G/1.35G [00:04<00:01, 289MB/s]
# model-00003-of-00003.safetensors:  78% 1.06G/1.35G [00:04<00:01, 286MB/s]
# model-00003-of-00003.safetensors:  80% 1.09G/1.35G [00:04<00:01, 270MB/s]
# model-00003-of-00003.safetensors:  82% 1.11G/1.35G [00:04<00:00, 264MB/s]
# model-00003-of-00003.safetensors:  84% 1.14G/1.35G [00:04<00:00, 269MB/s]
# model-00003-of-00003.safetensors:  86% 1.16G/1.35G [00:04<00:00, 255MB/s]
# model-00003-of-00003.safetensors:  88% 1.19G/1.35G [00:04<00:00, 244MB/s]
# model-00003-of-00003.safetensors:  90% 1.21G/1.35G [00:04<00:00, 245MB/s]
# model-00003-of-00003.safetensors:  92% 1.24G/1.35G [00:05<00:00, 251MB/s]
# model-00003-of-00003.safetensors:  93% 1.26G/1.35G [00:05<00:00, 243MB/s]
# model-00003-of-00003.safetensors:  95% 1.28G/1.35G [00:05<00:00, 235MB/s]
# model-00003-of-00003.safetensors:  97% 1.30G/1.35G [00:05<00:00, 233MB/s]
# model-00003-of-00003.safetensors:  98% 1.33G/1.35G [00:05<00:00, 230MB/s]
# model-00003-of-00003.safetensors: 1.35GB [00:05, 260MB/s]
# ⬇️ Downloaded: model-00003-of-00003.safetensors
# Processing files:  78% 7/9 [00:28<00:12,  6.14s/file]
# model.safetensors.index.json:   0% 0.00/120k [00:00<?, ?B/s]
# model.safetensors.index.json: 128kB [00:00, 879kB/s]
# ⬇️ Downloaded: model.safetensors.index.json
# Processing files:  89% 8/9 [00:28<00:04,  4.28s/file]
# preprocessor_config.json:   0% 0.00/351 [00:00<?, ?B/s]
# preprocessor_config.json: 16.0kB [00:00, 113kB/s]
# ⬇️ Downloaded: preprocessor_config.json
# Processing files: 100% 9/9 [00:28<00:00,  3.18s/file]
# 🎙️ Initializing VibeVoice ...
# Loading processor & model from /content/VibeVoice/VibeVoice-1.5B
# tokenizer_config.json: 7.23kB [00:00, 31.4MB/s]
# vocab.json: 2.78MB [00:00, 67.4MB/s]
# merges.txt: 1.67MB [00:00, 101MB/s]
# tokenizer.json: 7.03MB [00:00, 143MB/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Qwen2Tokenizer'.
# The class this function is called from is 'VibeVoiceTextTokenizerFast'.
# Loading checkpoint shards: 100% 3/3 [00:23<00:00,  7.90s/it]
# Language model attention: sdpa
# Found 9 voice files in /content/VibeVoice/demo/voices
# 🚀 Launching Gradio Demo...
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://833303b5590f9ed50b.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
#
# ✨ Full generation successful!
# 🎵 Audio: ./podcast_audio/podcast_output_7ecfa8.wav
# 📄 Timestamps: ./podcast_audio/podcast_output_7ecfa8.json
#
# Generating (active: 1/1):   4% 20/506 [00:05<01:44,  4.66it/s]
